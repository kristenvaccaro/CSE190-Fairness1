# %% [markdown]
# <a href="https://colab.research.google.com/github/kristenvaccaro/CSE190-Fairness1/blob/main/CSE190_Fairness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('Fairness_1.csv')
df2 = pd.read_csv('Fairness_2.csv')

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Income', 'Credit Score', 'Credit Limit',
#        'Secret Answer'],
#       dtype='object')

# %%
df = df1

# %%
df.plot(x='Income', y='Credit Limit', style='o')
# Out:
# <Axes: xlabel='Income'>

# %%
df.plot(x='Credit Score', y='Credit Limit', style='o')
# Out:
# <Axes: xlabel='Credit Score'>

# %%
colors = {0: 'red', 1: 'aqua'}
plt.scatter(df['Credit Score'], df['Credit Limit'], c=df['Secret Answer'].map(colors))
